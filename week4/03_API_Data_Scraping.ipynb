# %% [markdown]
# Big Data And Society: Lab 3
# =====

# %% [markdown]
# # APIs and Data Scraping: Getting Twitter Data

# %% [markdown]
# ### 0. Set up a Twitter Application
#
# This week we are going to scrape data from the Twitter API and make some plots! We are going to use the Twitter REST API, which lets us query and retreive samples of Tweets. To do this, you need API keys that are associated with your account. Your API keys are secret and unique to you and only you, and they gives you access to Twitter data through the API.
#
# There are a couple of ways to get Twitter data, the REST API is just one of them. The others are to set up a Streamer (which streams real time tweets), or to access the Firehose (this means everything!). Read [this article](https://brightplanet.com/2013/06/twitter-firehose-vs-twitter-api-whats-the-difference-and-why-should-you-care/) for a nice comparison between the methods.
#
# The Twitter REST API is best place to start and what we will use in class. Follow the following steps to get your keys.
#
# * Create a twitter account if you do not already have one.
# * Go to [https://apps.twitter.com/](https://apps.twitter.com/) and log in with your twitter credentials.
# * Click **"Create New App"** in the upper right corner
# * Fill out the form, give it a name like **data_getter_yourname** and a description, agree to the terms, and click **"Create your Twitter application"** *Note: The form will ask for a website. You can put the github.io page you made as the URL. **It is OK for your callback URL to be blank.***
# * In the next page, click on **Keys and Access Tokens** tab, and copy your "Consumer Key (API Key)" and "Consumer Key (API Secret)".
#
# We need a Python file that will contain the **Twitter** keys. It is never a good idea to host these keys on a public website like **github**, so one way to keep them private is importing the keys as a variable from a separate, untracked file. Open your text editor, and in the materials for the week, *PASTE* these keys into the **twitter-keys.py** file and save the file. Using this method, we can then import the keys and use them on a repeated basis, and we can choose not to put this file on Github. **Make sure they are saved as strings!**
#
# **!!IMPORTANT NOTE!! NEVER SAVE YOUR TWITTER_KEY.PY FILE TO GITHUB. IF YOU DO, PEOPLE CAN SEE YOUR KEYS AND USE THEM. KEEP THESE ON YOUR MACHINE.**

# %% [markdown]
# ### 1. Importing the Libraries and Twitter Keys
#
# We will be using **Twython**, a Python library that provides wrappers around Twitter's API. To install **Twython** on a terminal or the command line, run the following command:
#
# ```
# pip install twython
# ```
#
# We also need to import the keys we just got from Twitter to be accessible to our code. View the contents of **twitter_key.py** to see your keys. These should both be strings.
#
# ```
# # In the file you should define two variables:
# api_key = "your twitter key"
# api_secret = "your twitter secret"
# ```
#
# Import the libraries:

# %%
# Import libraries
import json
import time
import threading
from datetime import datetime
from twython import Twython

# Imports the keys from the python file
from twitter_key_cnavas import api_key, api_secret

# %% [markdown]
# ### 2. Set Up Twython, Get an OAuth2 Token, and Create your Twython Object
#
# In this next step, assign the keys to variables and set up our instance of Twython to work with your account.
#
# Doing this requires our authentication with Twitter using our keys. Twitter uses something called [OAuth](https://dev.twitter.com/oauth) for API authentication. There are two types of OAuth authentication. OAuth1 provides user authentication to the API, and is required to post tweets and issue requests on behalf of users. OAuth 2 is [application-only authentication](https://dev.twitter.com/oauth/application-only), and has higher rate limits but doesn't allow you to post on users behalf. Because we can get more tweets using it, we are going to use OAuth2.
#
# **OAuth 2 requires a Third Access token you must request using the API. This next step will set everything up for us.**
#
# In the last part of this, we create a **Twython** object and call it **my_twython**; this object simplifies the access to the [Twitter API](https://dev.twitter.com/overview/documentation), and provides methods for accessing the API’s endpoints. The first function fetches tweets with a given query at a given lat-long. We will be using the search parameters to hit the APIs endpoint. We need to provide the lat/lon of the centroid of the area we want to query, maximum number of tweets to return, and area within the centroid to search for, among others.

# %%
# Assigns the keys to the variables
APP_KEY = api_key
APP_SECRET = api_secret

# Create a Twython object called Twitter
# Set this up using your Twitter Keys
# Say we are going to use OAuth 2
twython_setup = Twython(APP_KEY, APP_SECRET, oauth_version=2)

# Get an OAuth2 access token, save as variable so we can launch our 
OAUTH2_ACCESS_TOKEN = twython_setup.obtain_access_token()

# Create a Twython Object we will use for our access to the API
my_twython = Twython(APP_KEY, access_token=OAUTH2_ACCESS_TOKEN)

# %% [markdown]
# For reference, the Twython documentation and all available commands can be found here. [https://twython.readthedocs.io/en/latest/usage/starting_out.html](https://twython.readthedocs.io/en/latest/usage/starting_out.html)

# %% [markdown]
# ### 3. Query the Twitter API to get Tweets at a Location
#
# Next, let's do a search and get some tweets! Specifically, set up a function that will use the **search** API. Read more about the **search** API [here](https://dev.twitter.com/rest/reference/get/search/tweets).
#
# The **Search API** can take many parameters for querying tweets. Twitter has a nice page of what you can use as query parameters here [https://dev.twitter.com/rest/public/search](https://dev.twitter.com/rest/public/search).
#
# The Twitter API has rate limits that limit how quickly you can download data. This is to try to lighten the load on their servers. We are using the Search API with **OAuth2 (Application) Access** - which limits us to **450 in 15 minutes** Read about the [Rate Limits](https://dev.twitter.com/rest/public/rate-limiting) here. This means, in our following steps, always follow the guideline that you will not be able to get more than 450 tweets in 15 minutes, or Twitter might lock your access.

# %%
# Input the search term you want to search on
search_term='bike' # SET A SEARCH TERM LIKE 'TRUMP'
# CAN LEAVE search_term BLANK IF YOU WANT ALL TWEETS NEAR A SPECIFIC LOCATION
# Setup a Lat Lon
latlong=[40.261455,-76.882553] # Downtown Harrisburg, PA - Capital of Pennsylvania
# Setup a search distance
distance='25mi'
# Set result type (can be 'recent', 'popular', or 'mixed')
type_of_result='recent'
# Set number of results (up to 100, remember you can only get 450 in 15 minutes)
number_of_tweets=15


# Fetches tweets with a given query at a given lat-long.
def get_tweets_by_location( latlong=None ):
    # Uses the search function to hit the APIs endpoints and look for recent tweets within the area
    results = my_twython.search(q=search_term, geocode=str(latlong[0])+','+str(latlong[1])+','+ distance, result_type=type_of_result, count=number_of_tweets)
    # Returns the only the statuses from the resulting JSON
    return results['statuses']

# test run our function
get_tweets_by_location(latlong)
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 18:46:41 +0000 2017',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838823164998205441,
#   'id_str': '838823164998205441',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': "Getting ready for Daytona bike week 🙌🏽🙌🏽🙌🏽 ugh can't wait fr I deserve this 🙏🏽😇🤘🏽 gone be such a long ride anyone wanna join ?",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Feb 06 10:57:33 +0000 2012',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 915,
#    'follow_request_sent': None,
#    'followers_count': 236,
#    'following': None,
#    'friends_count': 591,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 484664382,
#    'id_str': '484664382',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'columbia pa. ',
#    'name': 'mmgordie j-money',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/484664382/1352133685',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/3579960694/6100535767e820c715d64cb2f28f0e07_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3579960694/6100535767e820c715d64cb2f28f0e07_normal.jpeg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'GBEbangordie',
#    'statuses_count': 1317,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 18:29:28 +0000 2017',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/ADCXphbHeV',
#      'expanded_url': 'https://twitter.com/bird_inn/status/838818830222770176/photo/1',
#      'id': 838818822018711553,
#      'id_str': '838818822018711553',
#      'indices': [30, 53],
#      'media_url': 'http://pbs.twimg.com/media/C6QVRj1WQAEWqCx.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6QVRj1WQAEWqCx.jpg',
#      'sizes': {'large': {'h': 924, 'resize': 'fit', 'w': 687},
#       'medium': {'h': 924, 'resize': 'fit', 'w': 687},
#       'small': {'h': 680, 'resize': 'fit', 'w': 506},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/ADCXphbHeV'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': []},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/ADCXphbHeV',
#      'expanded_url': 'https://twitter.com/bird_inn/status/838818830222770176/photo/1',
#      'id': 838818822018711553,
#      'id_str': '838818822018711553',
#      'indices': [30, 53],
#      'media_url': 'http://pbs.twimg.com/media/C6QVRj1WQAEWqCx.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6QVRj1WQAEWqCx.jpg',
#      'sizes': {'large': {'h': 924, 'resize': 'fit', 'w': 687},
#       'medium': {'h': 924, 'resize': 'fit', 'w': 687},
#       'small': {'h': 680, 'resize': 'fit', 'w': 506},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/ADCXphbHeV'},
#     {'display_url': 'pic.twitter.com/ADCXphbHeV',
#      'expanded_url': 'https://twitter.com/bird_inn/status/838818830222770176/photo/1',
#      'id': 838818822014570497,
#      'id_str': '838818822014570497',
#      'indices': [30, 53],
#      'media_url': 'http://pbs.twimg.com/media/C6QVRj0XEAE76Q7.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6QVRj0XEAE76Q7.jpg',
#      'sizes': {'large': {'h': 1434, 'resize': 'fit', 'w': 2048},
#       'medium': {'h': 840, 'resize': 'fit', 'w': 1200},
#       'small': {'h': 476, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/ADCXphbHeV'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838818830222770176,
#   'id_str': '838818830222770176',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': "Yard's bike giveaway tonight! https://t.co/ADCXphbHeV",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Jan 15 02:39:08 +0000 2015',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'bluebirdinn.com',
#        'expanded_url': 'http://www.bluebirdinn.com',
#        'indices': [0, 22],
#        'url': 'http://t.co/NDRGcliikY'}]}},
#    'favourites_count': 0,
#    'follow_request_sent': None,
#    'followers_count': 14,
#    'following': None,
#    'friends_count': 1,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 2983412016,
#    'id_str': '2983412016',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 1,
#    'location': 'Cornwall, Pennsylvania',
#    'name': 'Blue Bird Inn',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/601552732214992897/PF2QwXIl_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/601552732214992897/PF2QwXIl_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'bird_inn',
#    'statuses_count': 239,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'http://t.co/NDRGcliikY',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 16:07:28 +0000 2017',
#   'entities': {'hashtags': [{'indices': [52, 66], 'text': 'ElectricBikes'}],
#    'symbols': [],
#    'urls': [{'display_url': 'gdfl.co/1VNOd59',
#      'expanded_url': 'http://gdfl.co/1VNOd59',
#      'indices': [67, 90],
#      'url': 'https://t.co/fHFdByWHW6'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838783097227341824,
#   'id_str': '838783097227341824',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#   'text': 'New gadget: Meet: WAVEeBIKE Hits the Big Leagues of #ElectricBikes https://t.co/fHFdByWHW6 Gadget Flow members get $200 off! 😍… …',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Jan 16 23:38:14 +0000 2017',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'All about new and upcoming Tech! Never get left behind again!',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': None,
#    'followers_count': 13,
#    'following': None,
#    'friends_count': 77,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 821139528467550208,
#    'id_str': '821139528467550208',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 11,
#    'location': 'York, PA',
#    'name': 'SpartanTech',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/821139528467550208/1484625627',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/821205151134445568/H3Eh5zoR_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/821205151134445568/H3Eh5zoR_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'SpartanTech3',
#    'statuses_count': 1141,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 15:57:37 +0000 2017',
#   'entities': {'hashtags': [{'indices': [35, 43], 'text': 'Cyclist'}],
#    'symbols': [],
#    'urls': [{'display_url': 'gdfl.co/2kKmDqF',
#      'expanded_url': 'http://gdfl.co/2kKmDqF',
#      'indices': [60, 83],
#      'url': 'https://t.co/TXNQMBOK8y'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838780616388792320,
#   'id_str': '838780616388792320',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#   'text': 'New gadget: Meet the brightspark_1 #Cyclist Safety Lighting https://t.co/TXNQMBOK8y Because night bike rides need that extra s… …',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Jan 16 23:38:14 +0000 2017',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'All about new and upcoming Tech! Never get left behind again!',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': None,
#    'followers_count': 13,
#    'following': None,
#    'friends_count': 77,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 821139528467550208,
#    'id_str': '821139528467550208',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 11,
#    'location': 'York, PA',
#    'name': 'SpartanTech',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/821139528467550208/1484625627',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/821205151134445568/H3Eh5zoR_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/821205151134445568/H3Eh5zoR_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'SpartanTech3',
#    'statuses_count': 1141,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 03:35:28 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'to.pbs.org/2mVbLZp',
#      'expanded_url': 'http://to.pbs.org/2mVbLZp',
#      'indices': [60, 83],
#      'url': 'https://t.co/wfUOmm66HI'}],
#    'user_mentions': [{'id': 14437914,
#      'id_str': '14437914',
#      'indices': [88, 97],
#      'name': 'PBS NewsHour',
#      'screen_name': 'NewsHour'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838593849392050176,
#   'id_str': '838593849392050176',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': "Keystone pipeline won't use U.S. steel despite Trump pledge https://t.co/wfUOmm66HI via @NewsHour Another Trump lie. Flim-Flam Man",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Aug 01 01:21:44 +0000 2012',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Retired Science Teacher, Coach, Single Dad.',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 13,
#    'follow_request_sent': None,
#    'followers_count': 12,
#    'following': None,
#    'friends_count': 68,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 729667405,
#    'id_str': '729667405',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 1,
#    'location': 'Hershey Pa',
#    'name': 'Timothy Landenberger',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/729667405/1428165886',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/584395353346207744/gXoFMlKA_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/584395353346207744/gXoFMlKA_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'hike2_bike',
#    'statuses_count': 370,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 02:56:37 +0000 2017',
#   'entities': {'hashtags': [{'indices': [58, 71], 'text': 'Wrestlemania'},
#     {'indices': [100, 112], 'text': 'WWEFastlane'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 52135300,
#      'id_str': '52135300',
#      'indices': [0, 9],
#      'name': 'Kofi Kingston',
#      'screen_name': 'TrueKofi'},
#     {'id': 533394907,
#      'id_str': '533394907',
#      'indices': [10, 18],
#      'name': 'ShinigamE',
#      'screen_name': 'WWEBigE'},
#     {'id': 41284429,
#      'id_str': '41284429',
#      'indices': [19, 34],
#      'name': 'Austin Creed @ Home',
#      'screen_name': 'XavierWoodsPhD'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838584071278235648,
#   'id_str': '838584071278235648',
#   'in_reply_to_screen_name': 'TrueKofi',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': 52135300,
#   'in_reply_to_user_id_str': '52135300',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Mobile Web (M5)</a>',
#   'text': '@TrueKofi @WWEBigE @XavierWoodsPhD Can I ride the bike to #Wrestlemania too!! 👏 "Ice Cream Rocks" 👏 #WWEFastlane',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Nov 22 05:57:01 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Mother of 3 / @WWE fanatic / YouTuber / Married to @justinotstott  #SDLive #RAW',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 604,
#    'follow_request_sent': None,
#    'followers_count': 3503,
#    'following': None,
#    'friends_count': 347,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 218384735,
#    'id_str': '218384735',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 1,
#    'location': 'Harrisburg, Pennsylvania',
#    'name': 'Heather Welsh',
#    'notifications': None,
#    'profile_background_color': '131516',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/453711930885021697/VPa_Oc1T.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/453711930885021697/VPa_Oc1T.jpeg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/218384735/1488568598',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/810839537555558400/u1FY_Gq9_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/810839537555558400/u1FY_Gq9_normal.jpg',
#    'profile_link_color': 'DE5185',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '4E8695',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'HeatherNWelsh',
#    'statuses_count': 1922,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 02:48:20 +0000 2017',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838581986025418752,
#   'id_str': '838581986025418752',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': '"You been sippin on somethin\', that\'s why you can\'t drive the bike" 😂',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Mar 11 01:51:21 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'just gonna tweet about wrestling from now on. backtolifehc',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 456,
#    'follow_request_sent': None,
#    'followers_count': 305,
#    'following': None,
#    'friends_count': 996,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 23702105,
#    'id_str': '23702105',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 3,
#    'location': 'Harrisburg, PA',
#    'name': 'KurtMillerB2L',
#    'notifications': None,
#    'profile_background_color': 'BADFCD',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/176985768/wallpaper_080617c.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/176985768/wallpaper_080617c.jpg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/23702105/1471825112',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/767406363567882240/0Ci8tJwo_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/767406363567882240/0Ci8tJwo_normal.jpg',
#    'profile_link_color': 'FF0000',
#    'profile_sidebar_border_color': 'F2E195',
#    'profile_sidebar_fill_color': 'FFF7CC',
#    'profile_text_color': '0C3E53',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'ThtsWhtKurtSaid',
#    'statuses_count': 4452,
#    'time_zone': 'Quito',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 02:21:25 +0000 2017',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 3,
#   'favorited': False,
#   'geo': None,
#   'id': 838575214329999360,
#   'id_str': '838575214329999360',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-76.450865, 40.319883],
#       [-76.391933, 40.319883],
#       [-76.391933, 40.355786],
#       [-76.450865, 40.355786]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Lebanon, PA',
#    'id': '3d66c4f797ae51e6',
#    'name': 'Lebanon',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/3d66c4f797ae51e6.json'},
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'ill have a bike by summertime 🏍',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Jun 02 17:57:00 +0000 2012',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Est. 1993🤘🏼 #34 #TeamLebron 🏆 #JetLife ✈️🤙🏼Zienna Grace Thomas ❤️👶🏼🌎 Instagram- @kthomas34',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 66688,
#    'follow_request_sent': None,
#    'followers_count': 1011,
#    'following': None,
#    'friends_count': 478,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 597611933,
#    'id_str': '597611933',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 5,
#    'location': '  7 1 7 ',
#    'name': 'kt 🤙🏼',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/597611933/1481120813',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/835319212763725825/HFpi8cAf_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/835319212763725825/HFpi8cAf_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'KThomas34_',
#    'statuses_count': 38068,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Mar 06 00:59:49 +0000 2017',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838554677880971264,
#   'id_str': '838554677880971264',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'Damn Jody got jumped by some lil niggas and they took his bike and his Alizé 😂😂😂😂',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Jul 26 03:25:07 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "6'5....27....Snapchat: bwarelaflare...Pennsylvania...11/25....Eagles, 76ers, Penn State Football, Harrisburg Cougars",
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'revcom.us/a/firstvol/cra…',
#        'expanded_url': 'http://www.revcom.us/a/firstvol/crack.htm',
#        'indices': [0, 23],
#        'url': 'https://t.co/da5QrvEdZH'}]}},
#    'favourites_count': 160166,
#    'follow_request_sent': None,
#    'followers_count': 5368,
#    'following': None,
#    'friends_count': 2069,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 60220819,
#    'id_str': '60220819',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 121,
#    'location': 'Harrisburg, PA',
#    'name': 'Oroku Saki',
#    'notifications': None,
#    'profile_background_color': '9AE4E8',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000096077137/c63976580ba99ed8239183e8dd4c6708.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000096077137/c63976580ba99ed8239183e8dd4c6708.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/60220819/1471216780',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/817051167960268800/le1YTYhi_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/817051167960268800/le1YTYhi_normal.jpg',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDFFCC',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'BWare_LaFlare',
#    'statuses_count': 382609,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/da5QrvEdZH',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 23:25:53 +0000 2017',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/XFhZw6OQ2K',
#      'expanded_url': 'https://twitter.com/harrisburgnews1/status/838531039182016512/photo/1',
#      'id': 838531036673798145,
#      'id_str': '838531036673798145',
#      'indices': [99, 122],
#      'media_url': 'http://pbs.twimg.com/media/C6MPiP4U8AE29MB.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6MPiP4U8AE29MB.jpg',
#      'sizes': {'large': {'h': 550, 'resize': 'fit', 'w': 550},
#       'medium': {'h': 550, 'resize': 'fit', 'w': 550},
#       'small': {'h': 550, 'resize': 'fit', 'w': 550},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/XFhZw6OQ2K'}],
#    'symbols': [],
#    'urls': [{'display_url': 'dlvr.it/NY4TJW',
#      'expanded_url': 'http://dlvr.it/NY4TJW',
#      'indices': [75, 98],
#      'url': 'https://t.co/rBENz1quHv'}],
#    'user_mentions': []},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/XFhZw6OQ2K',
#      'expanded_url': 'https://twitter.com/harrisburgnews1/status/838531039182016512/photo/1',
#      'id': 838531036673798145,
#      'id_str': '838531036673798145',
#      'indices': [99, 122],
#      'media_url': 'http://pbs.twimg.com/media/C6MPiP4U8AE29MB.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6MPiP4U8AE29MB.jpg',
#      'sizes': {'large': {'h': 550, 'resize': 'fit', 'w': 550},
#       'medium': {'h': 550, 'resize': 'fit', 'w': 550},
#       'small': {'h': 550, 'resize': 'fit', 'w': 550},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/XFhZw6OQ2K'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838531039182016512,
#   'id_str': '838531039182016512',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="https://dlvrit.com/" rel="nofollow">dlvr.it</a>',
#   'text': 'Smart Airwheel Backpack Electric Folding Bike E3 Leads a New-style of Life https://t.co/rBENz1quHv https://t.co/XFhZw6OQ2K',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Sep 07 06:26:24 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Harrisburg News Now gives you latest and detailed information about various categories like art &\r\nculture, business, celebrity, employment, and many more.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'harrisburgnewsnow.com',
#        'expanded_url': 'http://www.harrisburgnewsnow.com/',
#        'indices': [0, 22],
#        'url': 'http://t.co/WmgExY1Tsw'}]}},
#    'favourites_count': 0,
#    'follow_request_sent': None,
#    'followers_count': 109,
#    'following': None,
#    'friends_count': 1,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 808304034,
#    'id_str': '808304034',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 57,
#    'location': 'Harrisburg',
#    'name': 'Harrisburg News Now',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/685933934/470b18cca8dd103086fba26a397fe267.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/685933934/470b18cca8dd103086fba26a397fe267.jpeg',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2724076503/dee66d13860b483588d1fcf8e400a2ed_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2724076503/dee66d13860b483588d1fcf8e400a2ed_normal.png',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'harrisburgnews1',
#    'statuses_count': 54608,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'http://t.co/WmgExY1Tsw',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 15:36:38 +0000 2017',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/igHXhLCBcX',
#      'expanded_url': 'https://twitter.com/harrisburgnews1/status/838412946363441153/photo/1',
#      'id': 838412942978625536,
#      'id_str': '838412942978625536',
#      'indices': [99, 122],
#      'media_url': 'http://pbs.twimg.com/media/C6KkISlUsAA19es.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6KkISlUsAA19es.jpg',
#      'sizes': {'large': {'h': 550, 'resize': 'fit', 'w': 550},
#       'medium': {'h': 550, 'resize': 'fit', 'w': 550},
#       'small': {'h': 550, 'resize': 'fit', 'w': 550},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/igHXhLCBcX'}],
#    'symbols': [],
#    'urls': [{'display_url': 'dlvr.it/NXxlRL',
#      'expanded_url': 'http://dlvr.it/NXxlRL',
#      'indices': [75, 98],
#      'url': 'https://t.co/bsBg0FVpxX'}],
#    'user_mentions': []},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/igHXhLCBcX',
#      'expanded_url': 'https://twitter.com/harrisburgnews1/status/838412946363441153/photo/1',
#      'id': 838412942978625536,
#      'id_str': '838412942978625536',
#      'indices': [99, 122],
#      'media_url': 'http://pbs.twimg.com/media/C6KkISlUsAA19es.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6KkISlUsAA19es.jpg',
#      'sizes': {'large': {'h': 550, 'resize': 'fit', 'w': 550},
#       'medium': {'h': 550, 'resize': 'fit', 'w': 550},
#       'small': {'h': 550, 'resize': 'fit', 'w': 550},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/igHXhLCBcX'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838412946363441153,
#   'id_str': '838412946363441153',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="https://dlvrit.com/" rel="nofollow">dlvr.it</a>',
#   'text': 'Airwheel E3 smart backpack electric bike Brightens Fashionable Street Snap https://t.co/bsBg0FVpxX https://t.co/igHXhLCBcX',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Sep 07 06:26:24 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Harrisburg News Now gives you latest and detailed information about various categories like art &\r\nculture, business, celebrity, employment, and many more.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'harrisburgnewsnow.com',
#        'expanded_url': 'http://www.harrisburgnewsnow.com/',
#        'indices': [0, 22],
#        'url': 'http://t.co/WmgExY1Tsw'}]}},
#    'favourites_count': 0,
#    'follow_request_sent': None,
#    'followers_count': 109,
#    'following': None,
#    'friends_count': 1,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 808304034,
#    'id_str': '808304034',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 57,
#    'location': 'Harrisburg',
#    'name': 'Harrisburg News Now',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/685933934/470b18cca8dd103086fba26a397fe267.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/685933934/470b18cca8dd103086fba26a397fe267.jpeg',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2724076503/dee66d13860b483588d1fcf8e400a2ed_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2724076503/dee66d13860b483588d1fcf8e400a2ed_normal.png',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'harrisburgnews1',
#    'statuses_count': 54608,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'http://t.co/WmgExY1Tsw',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 08:22:06 +0000 2017',
#   'entities': {'hashtags': [{'indices': [52, 66], 'text': 'ElectricBikes'}],
#    'symbols': [],
#    'urls': [{'display_url': 'gdfl.co/1VNOd59',
#      'expanded_url': 'http://gdfl.co/1VNOd59',
#      'indices': [67, 90],
#      'url': 'https://t.co/fHFdByWHW6'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838303595745402881,
#   'id_str': '838303595745402881',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#   'text': 'New gadget: Meet: WAVEeBIKE Hits the Big Leagues of #ElectricBikes https://t.co/fHFdByWHW6 Gadget Flow members get $200 off! 😍… …',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Jan 16 23:38:14 +0000 2017',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'All about new and upcoming Tech! Never get left behind again!',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 0,
#    'follow_request_sent': None,
#    'followers_count': 13,
#    'following': None,
#    'friends_count': 77,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 821139528467550208,
#    'id_str': '821139528467550208',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 11,
#    'location': 'York, PA',
#    'name': 'SpartanTech',
#    'notifications': None,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/821139528467550208/1484625627',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/821205151134445568/H3Eh5zoR_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/821205151134445568/H3Eh5zoR_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'SpartanTech3',
#    'statuses_count': 1141,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 03:05:52 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/2jVOU1L',
#      'expanded_url': 'http://bit.ly/2jVOU1L',
#      'indices': [67, 90],
#      'url': 'https://t.co/TJkvlSQdPv'},
#     {'display_url': 'queue.vip/enfqrRK',
#      'expanded_url': 'http://queue.vip/enfqrRK',
#      'indices': [91, 114],
#      'url': 'https://t.co/YeR5Zjk8Qo'}],
#    'user_mentions': [{'id': 3291457550,
#      'id_str': '3291457550',
#      'indices': [7, 23],
#      'name': 'ComingSoon_Tech',
#      'screen_name': 'ComingSoon_Tech'},
#     {'id': 814710178767601664,
#      'id_str': '814710178767601664',
#      'indices': [26, 38],
#      'name': 'UrbanX E-Wheel',
#      'screen_name': 'urbanxwheel'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838224013071560705,
#   'id_str': '838224013071560705',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="https://www.queueat.com" rel="nofollow">QueueTech</a>',
#   'text': 'Now on @ComingSoon_Tech ➜ @urbanxwheel | The Electric Bike Wheel ➜ https://t.co/TJkvlSQdPv https://t.co/YeR5Zjk8Qo',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Mar 20 20:14:46 +0000 2009',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'flickr.com/photos/1414276…',
#        'expanded_url': 'http://www.flickr.com/photos/141427632@N06/',
#        'indices': [0, 23],
#        'url': 'https://t.co/TKEVxWmNt3'}]}},
#    'favourites_count': 3759,
#    'follow_request_sent': None,
#    'followers_count': 101,
#    'following': None,
#    'friends_count': 592,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 25567338,
#    'id_str': '25567338',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 2,
#    'location': 'Hershey, PA',
#    'name': 'Eugene',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25567338/1474161986',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/815740226236805124/5YBOeN8g_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/815740226236805124/5YBOeN8g_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'elmer2424',
#    'statuses_count': 1626,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/TKEVxWmNt3',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 03:01:23 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'queue.vip/bOgeLne',
#      'expanded_url': 'http://queue.vip/bOgeLne',
#      'indices': [40, 63],
#      'url': 'https://t.co/PChyFOZrIG'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838222882945843200,
#   'id_str': '838222882945843200',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'UrbanX | Electrify Your Bike in Seconds https://t.co/PChyFOZrIG',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Mar 20 20:14:46 +0000 2009',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'flickr.com/photos/1414276…',
#        'expanded_url': 'http://www.flickr.com/photos/141427632@N06/',
#        'indices': [0, 23],
#        'url': 'https://t.co/TKEVxWmNt3'}]}},
#    'favourites_count': 3759,
#    'follow_request_sent': None,
#    'followers_count': 101,
#    'following': None,
#    'friends_count': 592,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 25567338,
#    'id_str': '25567338',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 2,
#    'location': 'Hershey, PA',
#    'name': 'Eugene',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25567338/1474161986',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/815740226236805124/5YBOeN8g_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/815740226236805124/5YBOeN8g_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'elmer2424',
#    'statuses_count': 1626,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/TKEVxWmNt3',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sun Mar 05 00:12:07 +0000 2017',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/PzDb6jogXD',
#      'expanded_url': 'https://twitter.com/harrisburgnews1/status/838180286496047104/photo/1',
#      'id': 838180282486251521,
#      'id_str': '838180282486251521',
#      'indices': [99, 122],
#      'media_url': 'http://pbs.twimg.com/media/C6HQhqtUYAEz_Ru.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6HQhqtUYAEz_Ru.jpg',
#      'sizes': {'large': {'h': 800, 'resize': 'fit', 'w': 800},
#       'medium': {'h': 800, 'resize': 'fit', 'w': 800},
#       'small': {'h': 680, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/PzDb6jogXD'}],
#    'symbols': [],
#    'urls': [{'display_url': 'dlvr.it/NXjX1k',
#      'expanded_url': 'http://dlvr.it/NXjX1k',
#      'indices': [75, 98],
#      'url': 'https://t.co/U3cCo8vUEn'}],
#    'user_mentions': []},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/PzDb6jogXD',
#      'expanded_url': 'https://twitter.com/harrisburgnews1/status/838180286496047104/photo/1',
#      'id': 838180282486251521,
#      'id_str': '838180282486251521',
#      'indices': [99, 122],
#      'media_url': 'http://pbs.twimg.com/media/C6HQhqtUYAEz_Ru.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C6HQhqtUYAEz_Ru.jpg',
#      'sizes': {'large': {'h': 800, 'resize': 'fit', 'w': 800},
#       'medium': {'h': 800, 'resize': 'fit', 'w': 800},
#       'small': {'h': 680, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/PzDb6jogXD'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 838180286496047104,
#   'id_str': '838180286496047104',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="https://dlvrit.com/" rel="nofollow">dlvr.it</a>',
#   'text': 'Airwheel E3, E6 and R5 Smart Electric Bike Show Intelligent E-bikes Sample https://t.co/U3cCo8vUEn https://t.co/PzDb6jogXD',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Sep 07 06:26:24 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Harrisburg News Now gives you latest and detailed information about various categories like art &\r\nculture, business, celebrity, employment, and many more.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'harrisburgnewsnow.com',
#        'expanded_url': 'http://www.harrisburgnewsnow.com/',
#        'indices': [0, 22],
#        'url': 'http://t.co/WmgExY1Tsw'}]}},
#    'favourites_count': 0,
#    'follow_request_sent': None,
#    'followers_count': 109,
#    'following': None,
#    'friends_count': 1,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 808304034,
#    'id_str': '808304034',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 57,
#    'location': 'Harrisburg',
#    'name': 'Harrisburg News Now',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/685933934/470b18cca8dd103086fba26a397fe267.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/685933934/470b18cca8dd103086fba26a397fe267.jpeg',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2724076503/dee66d13860b483588d1fcf8e400a2ed_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2724076503/dee66d13860b483588d1fcf8e400a2ed_normal.png',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'harrisburgnews1',
#    'statuses_count': 54608,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'http://t.co/WmgExY1Tsw',
#    'utc_offset': None,
#    'verified': False}}]

# %% [markdown]
# ### 4. Automate it - Hit the API and Parse the Result
#
# We are going to create a function to help us repeatedly hit the API, and parse the result into a readable JSON that contains the things that we are interested in, and still stores the raw tweet as an additional property. The returned object is a Python `dict` that we can easily parse into another dictionary to later store as a JSON. Raw JSONs returned from the API have a specific structure.
#
# It can be sometimes hard to read a raw JSON. I find it easy to use some online parsers like [this]( http://jsonparseronline.com/) to look at the structure of the JSON, and only access what we care about.
#
# Note: Remember we are limited to 450 every 15 minutes.

# %%
# Does pretty much what its long name suggests.
def get_lots_of_tweets( latlong ):
    # Create a dictionary to parse the JSON
    all_tweets = {}
    
    # We will be hitting the API a number of times within the total time
    total_time = 10
    
    # Everytime we hit the API we subtract time from the total
    remaining_seconds = total_time
    interval = 5
    while remaining_seconds > 0: # loop and run the function while remaining seconds is greater than zero
        added = 0
        # Hit the Twitter API using our function
        new_tweets = get_tweets_by_location(latlong) # we set latlong above!
        # Parse the resulting JSON, and save the rest of the raw content
        for tweet in new_tweets:
            tid = tweet['id']
            if tid not in all_tweets:
                properties = {}
                if tweet['coordinates'] != None:
                    properties['lat'] = tweet['coordinates']['coordinates'][0]
                    properties['lon'] = tweet['coordinates']['coordinates'][1]
                else:
                    properties['lat'] = None
                    properties['lon'] = None
                properties['location'] = tweet['user']['location'] #This will get us the location associated with the profile
                properties['tweet_id'] = tid
                properties['content'] = tweet['text']
                properties['user'] = tweet['user']['id']
                properties['raw_source'] = tweet
                properties['data_point'] = 'none'
                properties['time'] = tweet['created_at']
                all_tweets[ tid ] = properties
                added += 1
        print("At %d seconds, added %d new tweets, for a total of %d" % ( total_time - remaining_seconds, added, len( all_tweets )))
        # We wait a few seconds and hit the API again
        time.sleep(interval)
        remaining_seconds -= interval
    print(str(len(all_tweets)) + ' Tweets retrieved.')
    # We return the final dictionary to work with in Python
    return all_tweets

# %% [markdown]
# ### 5. Run the Twitter Scraper
#
# We need to call the functions, and save the JSONs into a location. In this case, I made a folder called **data**, where I am saving all the new JSONS. We can run the code continuously utilizing some loop, or we can use libraries like [threading](https://docs.python.org/3.6/library/threading.html).
#
# *Make sure you have a folder named **data** in the directory with your notebook! This function will save our collected datafiles to it when it finishes running.*

# %%
# This function executes the the functions over a given period of time
def run_all():
    # This is the number of times the code will be executed. In this case, just once. 
    starting = 1
    while starting > 0:
        # Sometimes the API returns some errors, killing the whole script, so we setup try/except to make sure it keeps running
        try:
            t = get_lots_of_tweets( latlong )
            # We name every file with the current time
            timestr = time.strftime("%Y%m%d-%H%M%S")
            # We write a new JSON into the target path
            with open( 'data/' + '%stweets.json' %(timestr), 'w' ) as f:
                f.write(json.dumps(t))
            # we can use a library like threading to execute the run function continuously.
            threading.Timer(45, run_all).start()
            starting -= 1
        except:
            pass
    
run_all()
# Out:
# At 0 seconds, added 15 new tweets, for a total of 15
# At 5 seconds, added 0 new tweets, for a total of 15
# 15 Tweets retrieved.
# At 0 seconds, added 15 new tweets, for a total of 15
# At 5 seconds, added 0 new tweets, for a total of 15
# 15 Tweets retrieved.
# At 0 seconds, added 15 new tweets, for a total of 15
# At 5 seconds, added 0 new tweets, for a total of 15
# 15 Tweets retrieved.
# At 0 seconds, added 15 new tweets, for a total of 15
# At 5 seconds, added 0 new tweets, for a total of 15
# 15 Tweets retrieved.
# At 0 seconds, added 15 new tweets, for a total of 15
# At 5 seconds, added 0 new tweets, for a total of 15
# 15 Tweets retrieved.
# At 0 seconds, added 15 new tweets, for a total of 15
# At 5 seconds, added 0 new tweets, for a total of 15
# 15 Tweets retrieved.
# At 0 seconds, added 15 new tweets, for a total of 15
# At 5 seconds, added 0 new tweets, for a total of 15
# 15 Tweets retrieved.
# At 0 seconds, added 15 new tweets, for a total of 15
# At 5 seconds, added 0 new tweets, for a total of 15
# 15 Tweets retrieved.
# At 0 seconds, added 15 new tweets, for a total of 15
# At 5 seconds, added 0 new tweets, for a total of 15
# 15 Tweets retrieved.
# At 0 seconds, added 15 new tweets, for a total of 15
# At 5 seconds, added 0 new tweets, for a total of 15
# 15 Tweets retrieved.
# At 0 seconds, added 15 new tweets, for a total of 15
# At 5 seconds, added 0 new tweets, for a total of 15
# 15 Tweets retrieved.
# At 0 seconds, added 15 new tweets, for a total of 15
# At 5 seconds, added 0 new tweets, for a total of 15
# 15 Tweets retrieved.
# At 0 seconds, added 15 new tweets, for a total of 15
# At 5 seconds, added 0 new tweets, for a total of 15
# 15 Tweets retrieved.
# At 0 seconds, added 15 new tweets, for a total of 15
# At 5 seconds, added 0 new tweets, for a total of 15
# 15 Tweets retrieved.
# At 0 seconds, added 15 new tweets, for a total of 15
# At 0 seconds, added 15 new tweets, for a total of 15
# At 5 seconds, added 0 new tweets, for a total of 15
# 15 Tweets retrieved.
# At 0 seconds, added 15 new tweets, for a total of 15
# At 5 seconds, added 0 new tweets, for a total of 15
# 15 Tweets retrieved.
# At 0 seconds, added 15 new tweets, for a total of 15
# At 0 seconds, added 15 new tweets, for a total of 15
# At 5 seconds, added 0 new tweets, for a total of 15
# 15 Tweets retrieved.
# At 0 seconds, added 15 new tweets, for a total of 15
# At 0 seconds, added 15 new tweets, for a total of 15
# At 0 seconds, added 15 new tweets, for a total of 15
# At 0 seconds, added 15 new tweets, for a total of 15
# At 0 seconds, added 15 new tweets, for a total of 15
# At 5 seconds, added 0 new tweets, for a total of 15
# 15 Tweets retrieved.
# At 0 seconds, added 15 new tweets, for a total of 15
# At 5 seconds, added 0 new tweets, for a total of 15

# %% [markdown]
# ### 6. Let's Explore the Data we Saved to our Machine
#
# Let's look through the JSON we created and checkout some of the data we just downloaded. First, let's import a couple of additional libraries that will let us interact with our file system, use numpy and pandas, and create plots:

# %%
# Import some additional libraries that will allow us to plot and interact with the operating system
from os import listdir
from os.path import isfile, join
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Next, let's explore our data a bit. This following function will allow us to perform a visual examination of what we downloaded from Twitter. Once we have collected some data, we can parse it, and visualize some of the results. Since some of the data is repeated, we can initialize some lists to check whether or not a tweet already exists, and add it to the list. We can then extract the useful information for our purposes, and store it in another list.
#
# Building on last week, we can do this in Pandas.

# %%
# Get the file names from a given directory
file_dir = "data" # Set this to where your JSON saved
# Get only the JSONs we have saved
onlyfiles = [ f for f in listdir(file_dir) if isfile(join(file_dir,f)) and not f.startswith('.')]

# create an empty dataframe with columns for each property
df_tweets = pd.DataFrame(columns = ['tweet_id', 'lat', 'lon', 'content','location','user','raw_source','data_point','time'])

# Loop through all the files
for file in onlyfiles:
    full_dir = join(file_dir,file) 
    with open(full_dir) as json_data:
        dict = json.load(json_data) # creates a Python dictionary of our json
        if not isinstance(dict, list):
            for key, val in dict.items():
                df_tweets.loc[key,val] = val
                
df_tweets
# Out:
#                               tweet_id   lat   lon  \
# 838851051709169664  838851051709169664  None  None
# 838849762191364096  838849762191364096  None  None
# 838849449988395008  838849449988395008  None  None
# 838849104126046209  838849104126046209  None  None
# 838848688768299008  838848688768299008  None  None
# 838848433234526209  838848433234526209  None  None
# 838847647066779650  838847647066779650  None  None
# 838847172766498816  838847172766498816  None  None
# 838847149492183040  838847149492183040  None  None
# 838846910781870081  838846910781870081  None  None
# 838846387722809346  838846387722809346  None  None
# 838844452475035648  838844452475035648  None  None
# 838844246207705089  838844246207705089  None  None
# 838844165702168576  838844165702168576  None  None
# 838843267936563203  838843267936563203  None  None
# 838852245936553984  838852245936553984  None  None
#
#                                                               content  \
# 838851051709169664  So, the timing of these Trump/Russia leaks is ...
# 838849762191364096  Can Trump Supporters Legally Shoot Left-Wing “...
# 838849449988395008  What a sickening way to treat a veteran! Shame...
# 838849104126046209  RT @realJeffreyLord: Here’s A Supercut Of Anti...
# 838848688768299008  No bidders make offers to buy Trump tower in T...
# 838848433234526209  @DrMartyFox @LindaSuhler she doesn't understan...
# 838847647066779650  NYT may regret publishing this smoking gun:\nh...
# 838847172766498816  RT @realJeffreyLord: Here’s A Supercut Of Anti...
# 838847149492183040  RT @realJeffreyLord: Here’s A Supercut Of Anti...
# 838846910781870081  @nytpolitics Maybe that's what Clinton was tal...
# 838846387722809346  @BasedStickMan @BasedAuslander Exactly right! ...
# 838844452475035648  RT @realJeffreyLord: Here’s A Supercut Of Anti...
# 838844246207705089  RT @realJeffreyLord: Here’s A Supercut Of Anti...
# 838844165702168576  @SquawkCNBC Mostly trying to listen to your ma...
# 838843267936563203  RT @realJeffreyLord: Here’s A Supercut Of Anti...
# 838852245936553984  Mexico companies bid on wall const.If bid is b...
#
#                               location                user  \
# 838851051709169664          Harrisburg           741384337
# 838849762191364096       York, PA, USA            46930084
# 838849449988395008        Carlisle, PA  824828818766573568
# 838849104126046209                      837931097975566336
# 838848688768299008      Harrisburg, PA            16807304
# 838848433234526209  New Cumberland, PA           747579529
# 838847647066779650      Lewisberry, PA           412749418
# 838847172766498816           Wisconsin          1947550519
# 838847149492183040     California, USA           143352629
# 838846910781870081       Harrisburg Pa  827161112684658689
# 838846387722809346  New Cumberland, PA           747579529
# 838844452475035648                      733795265413545986
# 838844246207705089                      713733295859752960
# 838844165702168576            York, PA          1549521343
# 838843267936563203     no lists please          4843899317
# 838852245936553984   Pennsylvania, USA            29181351
#
#                                                            raw_source  \
# 838851051709169664  {'created_at': 'Mon Mar 06 20:37:30 +0000 2017...
# 838849762191364096  {'created_at': 'Mon Mar 06 20:32:23 +0000 2017...
# 838849449988395008  {'created_at': 'Mon Mar 06 20:31:08 +0000 2017...
# 838849104126046209  {'created_at': 'Mon Mar 06 20:29:46 +0000 2017...
# 838848688768299008  {'created_at': 'Mon Mar 06 20:28:07 +0000 2017...
# 838848433234526209  {'created_at': 'Mon Mar 06 20:27:06 +0000 2017...
# 838847647066779650  {'created_at': 'Mon Mar 06 20:23:58 +0000 2017...
# 838847172766498816  {'created_at': 'Mon Mar 06 20:22:05 +0000 2017...
# 838847149492183040  {'created_at': 'Mon Mar 06 20:22:00 +0000 2017...
# 838846910781870081  {'created_at': 'Mon Mar 06 20:21:03 +0000 2017...
# 838846387722809346  {'created_at': 'Mon Mar 06 20:18:58 +0000 2017...
# 838844452475035648  {'created_at': 'Mon Mar 06 20:11:17 +0000 2017...
# 838844246207705089  {'created_at': 'Mon Mar 06 20:10:27 +0000 2017...
# 838844165702168576  {'created_at': 'Mon Mar 06 20:10:08 +0000 2017...
# 838843267936563203  {'created_at': 'Mon Mar 06 20:06:34 +0000 2017...
# 838852245936553984  {'created_at': 'Mon Mar 06 20:42:15 +0000 2017...
#
#                    data_point                            time
# 838851051709169664       none  Mon Mar 06 20:37:30 +0000 2017
# 838849762191364096       none  Mon Mar 06 20:32:23 +0000 2017
# 838849449988395008       none  Mon Mar 06 20:31:08 +0000 2017
# 838849104126046209       none  Mon Mar 06 20:29:46 +0000 2017
# 838848688768299008       none  Mon Mar 06 20:28:07 +0000 2017
# 838848433234526209       none  Mon Mar 06 20:27:06 +0000 2017
# 838847647066779650       none  Mon Mar 06 20:23:58 +0000 2017
# 838847172766498816       none  Mon Mar 06 20:22:05 +0000 2017
# 838847149492183040       none  Mon Mar 06 20:22:00 +0000 2017
# 838846910781870081       none  Mon Mar 06 20:21:03 +0000 2017
# 838846387722809346       none  Mon Mar 06 20:18:58 +0000 2017
# 838844452475035648       none  Mon Mar 06 20:11:17 +0000 2017
# 838844246207705089       none  Mon Mar 06 20:10:27 +0000 2017
# 838844165702168576       none  Mon Mar 06 20:10:08 +0000 2017
# 838843267936563203       none  Mon Mar 06 20:06:34 +0000 2017
# 838852245936553984       none  Mon Mar 06 20:42:15 +0000 2017

# %% [markdown]
# ### 7. Summarize, Group, and Plot the Dataset
#
# Next let's summarize and group our data, and create some plots.
#
# **A** - First, group by the user location. This is not lat/lon, but rather the information the individual has input on their profile.
#
# When you give people the power to input their own location, you get an assortment of 'creative' responses!

# %%
df_tweets.dtypes
# Out:
# tweet_id      object
# lat           object
# lon           object
# content       object
# location      object
# user          object
# raw_source    object
# data_point    object
# time          object
# dtype: object

# %%
df_tweets['location'].unique()
# Out:
# array(['Harrisburg', 'York, PA, USA', 'Carlisle, PA', '', 'Harrisburg, PA',
#        'New Cumberland, PA', 'Lewisberry, PA', 'Wisconsin',
#        'California, USA', 'Harrisburg Pa', 'York, PA', 'no lists please',
#        'Pennsylvania, USA'], dtype=object)

# %% [markdown]
# Now let's do some grouping and sorting. We are using Pandas to do our analysis, much like last week.

# %%
grouped_tweets = df_tweets.groupby('location')
count_tweets = grouped_tweets['location'].count()
df_count_tweets = count_tweets.to_frame()
df_count_tweets.columns = ['Count']
df_count_tweets.index.names = ['Location']
df_count_tweets.sort_index()
# Out:
#                     Count
# Location
#                         3
# California, USA         1
# Carlisle, PA            1
# Harrisburg              1
# Harrisburg Pa           1
# Harrisburg, PA          1
# Lewisberry, PA          1
# New Cumberland, PA      2
# Pennsylvania, USA       1
# Wisconsin               1
# York, PA                1
# York, PA, USA           1
# no lists please         1

# %% [markdown]
# Let's create a pie chart of these using matplotlib.

# %%
# Create a list of colors (from iWantHue)
colors = ["#697dc6","#5faf4c","#7969de","#b5b246",
          "#cc54bc","#4bad89","#d84577","#4eacd7",
          "#cf4e33","#894ea8","#cf8c42","#d58cc9",
          "#737632","#9f4b75","#c36960"]

# Create a pie chart
plt.pie( df_count_tweets['Count'], labels=df_count_tweets.index.get_values(), shadow=False, colors=colors)

# View the plot drop above
plt.axis('equal')

# View the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# There are quite a few duplicates that we can clearly see, you will likely want to clean this data to rectify this.

# %% [markdown]
# **B** - Next, let's find how many actually have a location and put them on a scatterplot. To do this, we need to find first the rows where lat and long are not None, and then create the plot from just that subset of the data. Let's give it a go.

# %%
# Create a filter from df_tweets filtering only those that have values for lat and lon
df_tweets_with_location = df_tweets[df_tweets.lon.notnull() & df_tweets.lat.notnull()]
df_tweets_with_location
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-482441c17f70> in <module>()
#       1 # Create a filter from df_tweets filtering only those that have values for lat and lon
# ----> 2 df_tweets_with_location = df_tweets[df_tweets.lon.notnull() & df_tweets.lat.notnull()]
#       3 df_tweets_with_location
#
# NameError: name 'df_tweets' is not defined

# %%
# Use a scatter plot to make a quick visualization of the data points
# NOTE: WHEN I DID THIS, I ONLY HAD SIX OUT OF ABOUT 100 TWEETS!
plt.scatter(df_tweets_with_location['lon'],df_tweets_with_location['lat'], s=25)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-1dff57db92fa> in <module>()
#       1 # Use a scatter plot to make a quick visualization of the data points
#       2 # NOTE: WHEN I DID THIS, I ONLY HAD SIX OUT OF ABOUT 100 TWEETS!
# ----> 3 plt.scatter(df_tweets_with_location['lon'],df_tweets_with_location['lat'], s=25)
#       4 plt.show()
#
# /Users/cnavas/anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3433                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3434                          linewidths=linewidths, verts=verts,
# -> 3435                          edgecolors=edgecolors, data=data, **kwargs)
#    3436     finally:
#    3437         ax._hold = washold
#
# /Users/cnavas/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
#    1894         if pre_doc is None:
#
# /Users/cnavas/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    3993         maskargs = x, y, s, c, colors, edgecolors, linewidths
#    3994         x, y, s, c, colors, edgecolors, linewidths =\
# -> 3995             cbook.delete_masked_points(*maskargs)
#    3996
#    3997         scales = s   # Renamed for readability below.
#
# /Users/cnavas/anaconda/lib/python3.6/site-packages/matplotlib/cbook.py in delete_masked_points(*args)
#    1834         return ()
#    1835     if (is_string_like(args[0]) or not iterable(args[0])):
# -> 1836         raise ValueError("First argument must be a sequence")
#    1837     nrecs = len(args[0])
#    1838     margs = []
#
# ValueError: First argument must be a sequence

# %% [markdown]
# ### 8. Clean the Data
#
# **Clean the Locations** - You saw above that we had a bunch of locations that were very similar. Here, we could use [replace](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.replace.html). For example, we could replace all the variations of **York, PA** with a singular string using something like the following:

# %%
# List of variations of York
variations_of_york = ['York, PA','York PA','York, Pennsylvania','York, Pa','41 W Market Street York, Pa','york P.a. ','York, Pa.']

df_tweets['location'].replace(variations_of_york, 'York, PA')
# Out:
# 836956609368698882                Harrisburg, PA
# 836956602435502080               Kansas City, MO
# 836956591190605824                Harrisburg, PA
# 836956552649191424
# 836956526808035328    Miami, FL | #AmericaFirst
# 836956460437368832                 Uptown Dallas
# 836956403696742403                 United States
# 836956310700720128                   Atlanta, GA
# 836956308058189824
# 836956255692460034
# 836956252651438086                   Arizona USA
# 836956238508343296
# 836956157747032064           University Park, PA
# 836956044530180098                  Pennsylvania
# 836956006911455234       Deerfield Beach Florida
# 836962039847247872                           USA
# 836961817616396288                   Schertz, TX
# 836961664801124357
# 836961536736444416
# 836961463700971521
# 836961434542174210        Hilton Head Island, SC
# 836961297791135744                 Arkansas, USA
# 836961251007811589                 Virginia, USA
# 836961217583398912                Crown City, OH
# 836961044237008896                Wisconsin, USA
# 836961024808996869
# 836961003350949888
# 836960953946230784
# 836960948812464128                   Chicago, Il
# 836960940398641152                   NJ || KU'19
# 836962171951149057
# 836962164283961345
# Name: location, dtype: object

# %% [markdown]
# **Remove Duplicates** - Make sure that we don't get tweets plotted more than once. How would you make sure to only plot unique tweets? We can maybe use [drop_duplicates](http://chrisalbon.com/python/pandas_delete_duplicates.html)

# %% [markdown]
# ### 9. Exporting your Data to CSV
#
# Exporting your dataset is easy, you can use **to_csv()**. This [Stack Exchange](http://stackoverflow.com/questions/16923281/pandas-writing-dataframe-to-csv-file) page will help you.

# %%
df_tweets.to_csv('twitter_data.csv', sep=',', encoding='utf-8')

# %% [markdown]
# ### Problem Set 3 - Extend What You Have Learned
#
# Now that you know how to scrape data from Twitter, let's extend the exercise a little so you can show us what you know. This time you will set up the scraper to get data around MIT and scrape data for 20 minutes. Then you will visualize it with  and visualize. Think about what you would need to change to do that.
#
# Once you have the new JSON file of Boston tweets you should a pie chart and scatterplot of your collected tweets. When you are creating your dataset, you should get at least two different attributes returned by the Twitter API (we got many of them above, so base it off of that example). Atleast one of them should be the tweet id. Make sure you remove and duplicate tweets (if any). Expanding on the above, then save the data to a CSV.
#
# Make sure you get your own Twitter Key.
#
# #### Deliverables
#
# **1** - Using the Twitter REST API, collect Tweets from Boston for 30 min. Note how you set the time in the above example (in the **run_all()** function), it was in seconds. How would you do that here?
#
# **2** - Create a Pie Chart showing a summary of tweets by user location. Please clean up the data so that multiple variations of the same location name are replaced with one variation.
#
# **3** - Create a Scatterplot showing all of the tweets that had a latitude and longitude.
#
# **4** - Pick a search term, such as *Trump* or *#Trump* and collect 15 minutes of tweets on it. Use the same lat/lon for Boston as you used above.
#
# **5** - Export the entirety of your scraped Twitter datasets (one with a search term, one without) to two CSV files. We will be checking this CSV file for duplicates. So clean your file.
#
# ### What to Give Us on Stellar
#
# 1 - Create a new Jupyter notebook that contains your scraper code. You can copy much of this one, but customize it. Submit the new Jupyter notebook, which includes your pie chart and scatterplot.
#
# 2 - Your final CSV files.
